# %%
import pandas as pd

# %%
housing_2018 = pd.read_csv('data\ACSDP5Y2018.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2018 = housing_2018[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units']].copy()
housing_2018 = housing_2018.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units':'vacant_units'})

housing_2017 = pd.read_csv('data\ACSDP5Y2017.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2017 = housing_2017[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units']].copy()
housing_2017 = housing_2017.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units':'vacant_units'})
                                             
housing_2016 = pd.read_csv('data\ACSDP5Y2016.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2016 = housing_2016[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units']].copy()
housing_2016 = housing_2016.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units':'vacant_units'})

housing_2015 = pd.read_csv('data\ACSDP5Y2015.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2015 = housing_2015[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units']].copy()
housing_2015 = housing_2015.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units':'vacant_units'})

housing_2014 = pd.read_csv('data\ACSDP5Y2014.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2014 = housing_2014[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units']].copy()
housing_2014 = housing_2014.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units':'vacant_units'})

housing_2013 = pd.read_csv('data\ACSDP5Y2013.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2013 = housing_2013[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units']].copy()
housing_2013 = housing_2013.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units':'vacant_units'})

housing_2012 = pd.read_csv('data\ACSDP5Y2012.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2012 = housing_2012[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Vacant housing units']].copy()
housing_2012 = housing_2012.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Vacant housing units':'vacant_units'})

housing_2011 = pd.read_csv('data\ACSDP5Y2011.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2011 = housing_2011[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Vacant housing units']].copy()
housing_2011 = housing_2011.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Vacant housing units':'vacant_units'})

housing_2010 = pd.read_csv('data\ACSDP5Y2010.DP04_data_with_overlays_2020-01-30T070657.csv',header=1)
housing_2010 = housing_2010[['Geographic Area Name',
                             'Estimate!!HOUSING OCCUPANCY!!Occupied housing units',
                             'Estimate!!HOUSING OCCUPANCY!!Vacant housing units']].copy()
housing_2010 = housing_2010.rename(columns={'Geographic Area Name':'county',
                                             'Estimate!!HOUSING OCCUPANCY!!Occupied housing units':'occupied_units',
                                             'Estimate!!HOUSING OCCUPANCY!!Vacant housing units':'vacant_units'})

housing_2018['year'] = '2018'
housing_2017['year'] = '2017'
housing_2016['year'] = '2016'
housing_2015['year'] = '2015'
housing_2014['year'] = '2014'
housing_2013['year'] = '2013'
housing_2012['year'] = '2012'
housing_2011['year'] = '2011'
housing_2010['year'] = '2010'


housing = housing_2018.append([housing_2017,
                               housing_2016,
                               housing_2015,
                               housing_2014,
                               housing_2013,
                               housing_2012,
                               housing_2011,
                               housing_2010
                              ],sort=False)
housing
# Out:
#                      county  occupied_units  vacant_units  year
# 0        Adams County, Ohio           10835          2085  2018
# 1        Allen County, Ohio           40537          4526  2018
# 2      Ashland County, Ohio           20439          1811  2018
# 3    Ashtabula County, Ohio           37652          8455  2018
# 4       Athens County, Ohio           22620          3990  2018
# ..                      ...             ...           ...   ...
# 83  Washington County, Ohio           25373          3034  2010
# 84       Wayne County, Ohio           42395          3301  2010
# 85    Williams County, Ohio           14953          1767  2010
# 86        Wood County, Ohio           48636          4279  2010
# 87     Wyandot County, Ohio            9169           687  2010
#
# [792 rows x 4 columns]

# %%
housing['percent_occupied'] = housing['occupied_units']/(housing['occupied_units'] + housing['vacant_units'])
housing['total_units'] = housing['occupied_units'] + housing['vacant_units']
housing
# Out:
#                      county  occupied_units  vacant_units  year  \
# 0        Adams County, Ohio           10835          2085  2018
# 1        Allen County, Ohio           40537          4526  2018
# 2      Ashland County, Ohio           20439          1811  2018
# 3    Ashtabula County, Ohio           37652          8455  2018
# 4       Athens County, Ohio           22620          3990  2018
# ..                      ...             ...           ...   ...
# 83  Washington County, Ohio           25373          3034  2010
# 84       Wayne County, Ohio           42395          3301  2010
# 85    Williams County, Ohio           14953          1767  2010
# 86        Wood County, Ohio           48636          4279  2010
# 87     Wyandot County, Ohio            9169           687  2010
#
#     percent_occupied  total_units
# 0           0.838622        12920
# 1           0.899563        45063
# 2           0.918607        22250
# 3           0.816622        46107
# ...

# %%
housing.to_csv('data\housing_rates_over_time.csv')

# %%
import matplotlib
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
housing_3c = housing[housing.county.isin(['Cuyahoga County, Ohio',
                                         'Franklin County, Ohio',
                                         'Hamilton County, Ohio',
                                         ])]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,8)


sns.lineplot(x='year',
             y='total_units',
             data=housing_3c,
             hue='county'
            )

plt.title('Housing Occupancy Rates - 3 Cs',size=20)
plt.xlabel('Year',size=15)
plt.ylabel('Number of Housing Units',size=15)
#plt.xlim(1000, 82000)
#plt.legend(loc='upper right')
#plt.ylim(0, None)
#plt.text(1.59, 625, "Correlation = 0.44", horizontalalignment='right', size='medium', color='black', weight='semibold')
#plt.text(80000, 7500, "Non-Charter Correlation = .18", horizontalalignment='right', size='large', color='black', weight='semibold')
# Out:
# Text(0, 0.5, 'Number of Housing Units')
